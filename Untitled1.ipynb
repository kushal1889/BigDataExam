# %% [markdown]
# <a href="https://colab.research.google.com/github/kushal1889/BigDataExam/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn 
# %matplotlib inline

# %%
with open("adult.csv", 'r') as temp_f:
  col_count = [ len(l.split(",")) for l in temp_f.readlines() ]
  column_names = [i for i in range(0, max(col_count))]
df = pd.read_csv("adult.csv",header=None, delimiter=",", names=column_names)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,2,4,10,11,12,15,16,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header

# %%
df.shape
# Out:
# (48550, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48550 entries, 1 to 48550
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48550 non-null  object
#  1   workclass       48550 non-null  object
#  2   fnlwgt          48550 non-null  object
#  3   education       48550 non-null  object
#  4   education.num   48550 non-null  object
#  5   marital.status  48550 non-null  object
#  6   occupation      48550 non-null  object
#  7   relationship    48549 non-null  object
#  8   race            48549 non-null  object
#  9   sex             48549 non-null  object
#  10  capital.gain    48548 non-null  object
#  11  capital.loss    48548 non-null  object
#  12  hours.per.week  48548 non-null  object
#  13  native.country  48547 non-null  object
#  14  income          48547 non-null  object
#  15  nan             1 non-null      object
#  16  nan             1 non-null      object
# ...

# %%
df.isnull()
# Out:
# 0        age  workclass  fnlwgt  education  education.num  marital.status  \
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# 5      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 48546  False      False   False      False          False           False
# 48547  False      False   False      False          False           False
# 48548  False      False   False      False          False           False
# 48549  False      False   False      False          False           False
# 48550  False      False   False      False          False           False
#
# 0      occupation  relationship   race    sex  ...  income   NaN   NaN   NaN  \
# ...

# %%
df.isnull().sum()
# Out:
# 0
# age                   0
# workclass             0
# fnlwgt                0
# education             0
# education.num         0
# marital.status        0
# occupation            0
# relationship          1
# race                  1
# sex                   1
# capital.gain          2
# capital.loss          2
# hours.per.week        2
# native.country        3
# income                3
# NaN               48549
# NaN               48549
# NaN               48549
# NaN               48549
# NaN               48549
# NaN               48549
# NaN               48549
# NaN               48550
# NaN               48550
# dtype: int64

# %%
df.dtypes
# Out:
# 0
# age                object
# workclass          object
# fnlwgt             object
# education          object
# education.num      object
# marital.status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital.gain       object
# capital.loss       object
# hours.per.week     object
# native.country     object
# income             object
# NaN                object
# NaN                object
# NaN               float64
# NaN               float64
# NaN               float64
# NaN                object
# NaN                object
# NaN               float64
# NaN               float64
# dtype: object

# %%
df2=df

# %%
from sklearn.impute import SimpleImputer

# %%
df.describe()
# Out:
# 0      NaN  NaN   NaN  NaN  NaN
# count  1.0  1.0   1.0  0.0  0.0
# mean   0.0  0.0  20.0  NaN  NaN
# std    NaN  NaN   NaN  NaN  NaN
# min    0.0  0.0  20.0  NaN  NaN
# 25%    0.0  0.0  20.0  NaN  NaN
# 50%    0.0  0.0  20.0  NaN  NaN
# 75%    0.0  0.0  20.0  NaN  NaN
# max    0.0  0.0  20.0  NaN  NaN

# %%
df.head()
# Out:
# 0 age workclass  fnlwgt     education education.num marital.status  \
# 1  90         ?   77053       HS-grad             9        Widowed
# 2  82   Private  132870       HS-grad             9        Widowed
# 3  66         ?  186061  Some-college            10        Widowed
# 4  54   Private  140359       7th-8th             4       Divorced
# 5  41   Private  264663  Some-college            10      Separated
#
# 0         occupation   relationship   race     sex  ... income  NaN  NaN  NaN  \
# 1                  ?  Not-in-family  White  Female  ...  <=50K  NaN  NaN  NaN
# 2    Exec-managerial  Not-in-family  White  Female  ...  <=50K  NaN  NaN  NaN
# 3                  ?      Unmarried  Black  Female  ...  <=50K  NaN  NaN  NaN
# 4  Machine-op-inspct      Unmarried  White  Female  ...  <=50K  NaN  NaN  NaN
# 5     Prof-specialty      Own-child  White  Female  ...  <=50K  NaN  NaN  NaN
#
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
df2=df.dropna(thresh=100,axis=1)

# %%
df2.isnull().sum()
# Out:
# 0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      1
# race              1
# sex               1
# capital.gain      2
# capital.loss      2
# hours.per.week    2
# native.country    3
# income            3
# dtype: int64

# %%
df2.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object', name=0)

# %%
df2.head()
# Out:
# 0 age workclass  fnlwgt     education education.num marital.status  \
# 1  90         ?   77053       HS-grad             9        Widowed
# 2  82   Private  132870       HS-grad             9        Widowed
# 3  66         ?  186061  Some-college            10        Widowed
# 4  54   Private  140359       7th-8th             4       Divorced
# 5  41   Private  264663  Some-college            10      Separated
#
# 0         occupation   relationship   race     sex capital.gain capital.loss  \
# 1                  ?  Not-in-family  White  Female            0         4356
# 2    Exec-managerial  Not-in-family  White  Female            0         4356
# 3                  ?      Unmarried  Black  Female            0         4356
# 4  Machine-op-inspct      Unmarried  White  Female            0         3900
# 5     Prof-specialty      Own-child  White  Female            0         3900
#
# 0 hours.per.week native.country income
# 1             40  United-States  <=50K
# ...

# %%
import missingno as msno
import matplotlib.pyplot as plt
msno.bar(df2, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:xlabel='0'>

# %%
df2.fillna("Null", inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
msno.bar(df2, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:xlabel='0'>

# %%
df2.head()
# Out:
# 0 age workclass  fnlwgt     education education.num marital.status  \
# 1  90         ?   77053       HS-grad             9        Widowed
# 2  82   Private  132870       HS-grad             9        Widowed
# 3  66         ?  186061  Some-college            10        Widowed
# 4  54   Private  140359       7th-8th             4       Divorced
# 5  41   Private  264663  Some-college            10      Separated
#
# 0         occupation   relationship   race     sex capital.gain capital.loss  \
# 1                  ?  Not-in-family  White  Female            0         4356
# 2    Exec-managerial  Not-in-family  White  Female            0         4356
# 3                  ?      Unmarried  Black  Female            0         4356
# 4  Machine-op-inspct      Unmarried  White  Female            0         3900
# 5     Prof-specialty      Own-child  White  Female            0         3900
#
# 0 hours.per.week native.country income
# 1             40  United-States  <=50K
# ...

# %%
df2.isnull().sum()
# Out:
# 0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48550 entries, 1 to 48550
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48550 non-null  object
#  1   workclass       48550 non-null  object
#  2   fnlwgt          48550 non-null  object
#  3   education       48550 non-null  object
#  4   education.num   48550 non-null  object
#  5   marital.status  48550 non-null  object
#  6   occupation      48550 non-null  object
#  7   relationship    48550 non-null  object
#  8   race            48550 non-null  object
#  9   sex             48550 non-null  object
#  10  capital.gain    48550 non-null  object
#  11  capital.loss    48550 non-null  object
#  12  hours.per.week  48550 non-null  object
#  13  native.country  48550 non-null  object
#  14  income          48550 non-null  object
# dtypes: object(15)
# memory usage: 5.6+ MB

# %%
plt.hist(df2["sex"])
# Out:
# (array([1.6296e+04, 0.0000e+00, 3.2251e+04, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df2["education"])
# Out:
# (array([2.6677e+04, 2.3930e+03, 1.3740e+03, 7.8410e+03, 4.2540e+03,
#         3.6750e+03, 2.5700e+02, 1.1930e+03, 8.8400e+02, 2.0000e+00]),
#  array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df2[["income"]]
y = df2[["sex"]]
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size = 0.80)

# %%
from sklearn.tree import DecisionTreeClassifier as DTC

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
DTC.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-9f2a6dbadce3> in <module>
# ----> 1 DTC.fit(X_train,y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'
